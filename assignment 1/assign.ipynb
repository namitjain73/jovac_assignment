# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#task1
data = [25, 30, 35, 40, 45]
series = pd.Series(data, index=['A', 'B', 'C', 'D', 'E'])
print(series)
# Out:
# A    25
# B    30
# C    35
# D    40
# E    45
# dtype: int64

# %%
print('First three :\n',series.head(3))
# Out:
# First three :
#  A    25
# B    30
# C    35
# dtype: int64

# %%
mean = series.mean()
med = series.median()
std = series.std()

print("Mean :",mean)
print('Median :',med)
print("Standard Deviation ;",std)
# Out:
# Mean : 35.0
# Median : 35.0
# Standard Deviation ; 7.905694150420948

# %%
#task2
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, 20],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78
# 2  Carol   19  Female     92
# 3  David   21    Male     74
# 4    Eve   20  Female     88

# %%
print("First two row:\n")
df.head(2)
# Out:
# First two row:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78

# %%
print("Column Names:", df.columns.tolist())
print()
print("Data Types:\n", df.dtypes)
# Out:
# Column Names: ['Name', 'Age', 'Gender', 'Marks']
#
# Data Types:
#  Name      object
# Age        int64
# Gender    object
# Marks      int64
# dtype: object

# %%
print("Summary Statistics")
df.describe()
# Out:
# Summary Statistics
#              Age      Marks
# count   5.000000   5.000000
# mean   20.400000  83.400000
# std     1.140175   7.334848
# min    19.000000  74.000000
# 25%    20.000000  78.000000
# 50%    20.000000  85.000000
# 75%    21.000000  88.000000
# max    22.000000  92.000000

# %%
df['Passed'] = df['Marks'] >= 80
df
# Out:
#     Name  Age  Gender  Marks  Passed
# 0  Alice   20  Female     85    True
# 1    Bob   22    Male     78   False
# 2  Carol   19  Female     92    True
# 3  David   21    Male     74   False
# 4    Eve   20  Female     88    True

# %%
#task3


df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78
# 2  Carol   19  Female     92
# 3  David   21    Male     74
# 4    Eve   20  Female     88

# %%
print("Name and Marks columns:")
df[['Name', 'Marks']]
# Out:
# Name and Marks columns:
#     Name  Marks
# 0  Alice     85
# 1    Bob     78
# 2  Carol     92
# 3  David     74
# 4    Eve     88

# %%
fil_df = df[df['Marks'] > 80]
fil_df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 2  Carol   19  Female     92
# 4    Eve   20  Female     88

# %%
max_marks = df['Marks'].max()
student = df[df['Marks'] == max_marks]
student
# Out:
#     Name  Age  Gender  Marks
# 2  Carol   19  Female     92

# %%
#task4
df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78
# 2  Carol   19  Female     92
# 3  David   21    Male     74
# 4    Eve   20  Female     88

# %%
df.loc[1, 'Marks'] = None
df.loc[4, 'Age'] = None

# %%
df.isnull()
# Out:
#     Name    Age  Gender  Marks
# 0  False  False   False  False
# 1  False  False   False   True
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False   True   False  False

# %%
marks_mean = df['Marks'].mean()
df['Marks'].fillna(marks_mean, inplace=True)
df
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00
# 4    Eve   NaN  Female  88.00

# %%
df.dropna(subset=['Age'])
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00

# %%
#task5
df
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00
# 4    Eve   NaN  Female  88.00

# %%
mean_stats = df.groupby('Gender')[['Age', 'Marks']].mean()
mean_stats
# Out:
#          Age      Marks
# Gender
# Female  19.5  88.333333
# Male    21.5  79.375000

# %%
c = df['Gender'].value_counts()
c
# Out:
# Female    3
# Male      2
# Name: Gender, dtype: int64

# %%
#task6


data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, None],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, None, 92, 74, 88]
}
df = pd.DataFrame(data)
df
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female   85.0
# 1    Bob  22.0    Male    NaN
# 2  Carol  19.0  Female   92.0
# 3  David  21.0    Male   74.0
# 4    Eve   NaN  Female   88.0

# %%
df.to_csv("students_data.csv", index=False)

# %%
df_loaded = pd.read_csv("students_data.csv")
df_loaded
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female   85.0
# 1    Bob  22.0    Male    NaN
# 2  Carol  19.0  Female   92.0
# 3  David  21.0    Male   74.0
# 4    Eve   NaN  Female   88.0

# %%
df_loaded.head(5)
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female   85.0
# 1    Bob  22.0    Male    NaN
# 2  Carol  19.0  Female   92.0
# 3  David  21.0    Male   74.0
# 4    Eve   NaN  Female   88.0

# %%
#task7
df = pd.read_csv("Area_Population_Density_and_Population_2011_Census.csv")
df.columns = df.columns.str.strip()

df
# Out:
#               District  Geograpical Area (Sq.Kms)  Population Density  \
# 0             Mudalagi                      397.0               538.0
# 1           Jamakhandi                      882.0               307.0
# 2               Bilagi                      781.0               206.0
# 3               Mudhol                      859.0               287.0
# 4               Badami                     1069.0               227.0
# 5            Bagalkote                      935.0               307.0
# 6              Hungund                      733.0               218.0
# 7          Guledagudda                      316.0               275.0
# 8                Ilkal                      626.0               258.0
# 9   Rabakavi Banahatti                      351.0               732.0
# 10                 ...                        NaN                 NaN
#
#         Male    Female     Total  Percentage Share to Total Population  Rank
# 0   107522.0  106249.0  213771.0                                  4.47  12.0
# 1   132591.0  131380.0  263971.0                                 13.97   3.0
# 2    80147.0   80147.0  160294.0                                  8.48   7.0
# 3   124999.0  125194.0  250193.0                                 13.24   4.0
# 4   121871.0  119544.0  241415.0                                 12.77   5.0
# 5   143220.0  141894.0  285114.0                                 15.09   1.0
# 6    77228.0   75981.0  153209.0                                  8.11   8.0
# 7    44877.0   44568.0   89445.0                                  4.73   9.0
# 8    84513.0   83616.0  168129.0                                  8.90   6.0
# 9   140665.0  137317.0  277982.0                                 14.71   2.0
# 10       NaN       NaN       NaN                                   NaN   NaN

# %%
print("First 5 Rows of the Dataset:\n")
df.head()
# Out:
# First 5 Rows of the Dataset:
#      District  Geograpical Area (Sq.Kms)  Population Density      Male  \
# 0    Mudalagi                      397.0               538.0  107522.0
# 1  Jamakhandi                      882.0               307.0  132591.0
# 2      Bilagi                      781.0               206.0   80147.0
# 3      Mudhol                      859.0               287.0  124999.0
# 4      Badami                     1069.0               227.0  121871.0
#
#      Female     Total  Percentage Share to Total Population  Rank
# 0  106249.0  213771.0                                  4.47  12.0
# 1  131380.0  263971.0                                 13.97   3.0
# 2   80147.0  160294.0                                  8.48   7.0
# 3  125194.0  250193.0                                 13.24   4.0
# 4  119544.0  241415.0                                 12.77   5.0

# %%
df.columns.str.strip()
# Out:
# Index(['District', 'Geograpical Area (Sq.Kms)', 'Population Density', 'Male',
#        'Female', 'Total', 'Percentage Share to Total Population', 'Rank'],
#       dtype='object')

# %%
print("Dataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   District                              11 non-null     object
#  1   Geograpical Area (Sq.Kms)             10 non-null     float64
#  2   Population Density                    10 non-null     float64
#  3   Male                                  10 non-null     float64
#  4   Female                                10 non-null     float64
#  5   Total                                 10 non-null     float64
#  6   Percentage Share to Total Population  10 non-null     float64
#  7   Rank                                  10 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 832.0+ bytes

# %%
print("Summary Statistics:")
df.describe(include='all')
# Out:
# Summary Statistics:
#         District  Geograpical Area (Sq.Kms)  Population Density  \
# count         11                  10.000000           10.000000
# unique        11                        NaN                 NaN
# top     Mudalagi                        NaN                 NaN
# freq           1                        NaN                 NaN
# mean         NaN                 694.900000          335.500000
# std          NaN                 263.253764          168.064306
# min          NaN                 316.000000          206.000000
# 25%          NaN                 454.250000          234.750000
# 50%          NaN                 757.000000          281.000000
# 75%          NaN                 876.250000          307.000000
# max          NaN                1069.000000          732.000000
#
#                  Male         Female          Total  \
# count       10.000000      10.000000      10.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean    105763.300000  104589.000000  210352.300000
# std      32664.279937   32127.752866   64785.531397
# min      44877.000000   44568.000000   89445.000000
# 25%      81238.500000   81014.250000  162252.750000
# 50%     114696.500000  112896.500000  227593.000000
# 75%     130693.000000  129833.500000  260526.500000
# max     143220.000000  141894.000000  285114.000000
#
#         Percentage Share to Total Population      Rank
# count                               10.00000  10.00000
# unique                                   NaN       NaN
# top                                      NaN       NaN
# freq                                     NaN       NaN
# mean                                10.44700   5.70000
# std                                  4.02039   3.40098
# min                                  4.47000   1.00000
# 25%                                  8.20250   3.25000
# 50%                                 10.83500   5.50000
# 75%                                 13.78750   7.75000
# max                                 15.09000  12.00000

# %%
df.isnull().sum()
# Out:
# District                                0
# Geograpical Area (Sq.Kms)               1
# Population Density                      1
# Male                                    1
# Female                                  1
# Total                                   1
# Percentage Share to Total Population    1
# Rank                                    1
# dtype: int64

# %%
top10 =df.sort_values(by='Population Density', ascending=False).head(10)
top10
# Out:
#              District  Geograpical Area (Sq.Kms)  Population Density  \
# 9  Rabakavi Banahatti                      351.0               732.0
# 0            Mudalagi                      397.0               538.0
# 1          Jamakhandi                      882.0               307.0
# 5           Bagalkote                      935.0               307.0
# 3              Mudhol                      859.0               287.0
# 7         Guledagudda                      316.0               275.0
# 8               Ilkal                      626.0               258.0
# 4              Badami                     1069.0               227.0
# 6             Hungund                      733.0               218.0
# 2              Bilagi                      781.0               206.0
#
#        Male    Female     Total  Percentage Share to Total Population  Rank
# 9  140665.0  137317.0  277982.0                                 14.71   2.0
# 0  107522.0  106249.0  213771.0                                  4.47  12.0
# 1  132591.0  131380.0  263971.0                                 13.97   3.0
# 5  143220.0  141894.0  285114.0                                 15.09   1.0
# 3  124999.0  125194.0  250193.0                                 13.24   4.0
# 7   44877.0   44568.0   89445.0                                  4.73   9.0
# 8   84513.0   83616.0  168129.0                                  8.90   6.0
# 4  121871.0  119544.0  241415.0                                 12.77   5.0
# 6   77228.0   75981.0  153209.0                                  8.11   8.0
# 2   80147.0   80147.0  160294.0                                  8.48   7.0

# %%
df.columns = df.columns.str.strip()
plt.figure(figsize=(10, 6))
sns.barplot(x='Total', y='District', data=top10, hue='District', palette='rocket',orient='h')

plt.title('Top 10 Districts by Total Population')
plt.xlabel('Total Population')
plt.ylabel('District')
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df, x='Geograpical Area (Sq.Kms)', y='Population Density')
plt.title('Geographical Area vs Population Density')
plt.xlabel('Area (Sq.Kms)')
plt.ylabel('Population Density')
plt.tight_layout()
plt.show()
